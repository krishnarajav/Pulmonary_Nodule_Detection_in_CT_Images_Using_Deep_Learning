# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import pickle

# %%
# Mount Google Drive
from google.colab import drive
drive.mount("drive")
# Out:
# Mounted at drive

# %%
# Load data
trainX = np.load("drive/MyDrive/Datasets/lc/v4/trainX.npy").astype(np.float32) / 255.0
trainY = (np.load("drive/MyDrive/Datasets/lc/v4/trainY.npy").astype(np.float32) > 127).astype(np.float32)
testX = np.load("drive/MyDrive/Datasets/lc/v4/testX.npy").astype(np.float32) / 255.0
testY = (np.load("drive/MyDrive/Datasets/lc/v4/testY.npy").astype(np.float32) > 127).astype(np.float32)

# %%
# Reshape data
trainX = np.reshape(trainX, (len(trainX), 512, 512, 1))
trainY = np.reshape(trainY, (len(trainY), 512, 512, 1))
testX = np.reshape(testX, (len(testX), 512, 512, 1))
testY = np.reshape(testY, (len(testY), 512, 512, 1))

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
# U-Net model
def unet(input_size=(512, 512, 1)):
    inputs = Input(input_size)
    K.set_image_data_format('channels_last')

    # Encoder
    conv1 = Conv2D(32, (3, 3), activation="relu", padding="same")(inputs)
    conv1 = Conv2D(32, (3, 3), activation="relu", padding="same")(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation="relu", padding="same")(pool1)
    conv2 = Conv2D(64, (3, 3), activation="relu", padding="same")(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation="relu", padding="same")(pool2)
    conv3 = Conv2D(128, (3, 3), activation="relu", padding="same")(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation="relu", padding="same")(pool3)
    conv4 = Conv2D(256, (3, 3), activation="relu", padding="same")(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    # Bottleneck
    conv5 = Conv2D(512, (3, 3), activation="relu", padding="same")(pool4)
    conv5 = Conv2D(512, (3, 3), activation="relu", padding="same")(conv5)

    # Decoder
    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding="same")(conv5), conv4])
    conv6 = Conv2D(256, (3, 3), activation="relu", padding="same")(up6)
    conv6 = Conv2D(256, (3, 3), activation="relu", padding="same")(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding="same")(conv6), conv3])
    conv7 = Conv2D(128, (3, 3), activation="relu", padding="same")(up7)
    conv7 = Conv2D(128, (3, 3), activation="relu", padding="same")(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding="same")(conv7), conv2])
    conv8 = Conv2D(64, (3, 3), activation="relu", padding="same")(up8)
    conv8 = Conv2D(64, (3, 3), activation="relu", padding="same")(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding="same")(conv8), conv1])
    conv9 = Conv2D(32, (3, 3), activation="relu", padding="same")(up9)
    conv9 = Conv2D(32, (3, 3), activation="relu", padding="same")(conv9)

    conv10 = Conv2D(1, (1, 1), activation="sigmoid")(conv9)

    return Model(inputs, conv10)

# %%
# TPU setup
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
strategy = tf.distribute.TPUStrategy(resolver)

# %%
# Compile model
with strategy.scope():
    model = unet(input_size=(512, 512, 1))
    model.compile(optimizer=Adam(learning_rate=2e-4), loss=dice_coef_loss, metrics=[dice_coef, 'binary_accuracy'])

# %%
# Callbacks
checkpoint = ModelCheckpoint("checkpoint-{epoch:03d}-{val_dice_coef:.3f}.hdf5", monitor='val_dice_coef',
                             verbose=1, save_best_only=True, mode='max', save_weights_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=3, verbose=1, min_lr=1e-6)
early_stop = EarlyStopping(monitor="val_loss", patience=30, verbose=1, mode='min')

callbacks = [checkpoint, reduce_lr, early_stop]

# %%
# Train the model
history = model.fit(trainX, trainY, batch_size=32, epochs=250, validation_data=(testX, testY), callbacks=callbacks)
# Out:
# Epoch 1/250
# 169/169 [==============================] - ETA: 0s - loss: -0.0388 - dice_coef: 0.0396 - binary_accuracy: 0.8485
# Epoch 1: val_dice_coef improved from -inf to 0.11273, saving model to checkpoint-001-0.113.hdf5
# 169/169 [==============================] - 246s 1s/step - loss: -0.0388 - dice_coef: 0.0396 - binary_accuracy: 0.8485 - val_loss: -0.0937 - val_dice_coef: 0.1127 - val_binary_accuracy: 0.9980 - lr: 2.0000e-04
# Epoch 2/250
# 169/169 [==============================] - ETA: 0s - loss: -0.2984 - dice_coef: 0.2991 - binary_accuracy: 0.9985
# Epoch 2: val_dice_coef improved from 0.11273 to 0.42217, saving model to checkpoint-002-0.422.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.2984 - dice_coef: 0.2991 - binary_accuracy: 0.9985 - val_loss: -0.4132 - val_dice_coef: 0.4222 - val_binary_accuracy: 0.9991 - lr: 2.0000e-04
# Epoch 3/250
# 169/169 [==============================] - ETA: 0s - loss: -0.4767 - dice_coef: 0.4772 - binary_accuracy: 0.9992
# Epoch 3: val_dice_coef improved from 0.42217 to 0.51288, saving model to checkpoint-003-0.513.hdf5
# 169/169 [==============================] - 52s 310ms/step - loss: -0.4767 - dice_coef: 0.4772 - binary_accuracy: 0.9992 - val_loss: -0.5062 - val_dice_coef: 0.5129 - val_binary_accuracy: 0.9993 - lr: 2.0000e-04
# Epoch 4/250
# 169/169 [==============================] - ETA: 0s - loss: -0.5520 - dice_coef: 0.5523 - binary_accuracy: 0.9994
# Epoch 4: val_dice_coef improved from 0.51288 to 0.53894, saving model to checkpoint-004-0.539.hdf5
# 169/169 [==============================] - 53s 315ms/step - loss: -0.5520 - dice_coef: 0.5523 - binary_accuracy: 0.9994 - val_loss: -0.5307 - val_dice_coef: 0.5389 - val_binary_accuracy: 0.9994 - lr: 2.0000e-04
# Epoch 5/250
# 169/169 [==============================] - ETA: 0s - loss: -0.5906 - dice_coef: 0.5910 - binary_accuracy: 0.9994
# Epoch 5: val_dice_coef improved from 0.53894 to 0.60605, saving model to checkpoint-005-0.606.hdf5
# 169/169 [==============================] - 52s 311ms/step - loss: -0.5906 - dice_coef: 0.5910 - binary_accuracy: 0.9994 - val_loss: -0.5995 - val_dice_coef: 0.6061 - val_binary_accuracy: 0.9995 - lr: 2.0000e-04
# Epoch 6/250
# 169/169 [==============================] - ETA: 0s - loss: -0.6122 - dice_coef: 0.6122 - binary_accuracy: 0.9995
# Epoch 6: val_dice_coef improved from 0.60605 to 0.62904, saving model to checkpoint-006-0.629.hdf5
# 169/169 [==============================] - 52s 311ms/step - loss: -0.6122 - dice_coef: 0.6122 - binary_accuracy: 0.9995 - val_loss: -0.6223 - val_dice_coef: 0.6290 - val_binary_accuracy: 0.9994 - lr: 2.0000e-04
# Epoch 7/250
# 169/169 [==============================] - ETA: 0s - loss: -0.6100 - dice_coef: 0.6102 - binary_accuracy: 0.9995
# Epoch 7: val_dice_coef did not improve from 0.62904
# 169/169 [==============================] - 52s 310ms/step - loss: -0.6100 - dice_coef: 0.6102 - binary_accuracy: 0.9995 - val_loss: -0.5808 - val_dice_coef: 0.5869 - val_binary_accuracy: 0.9994 - lr: 2.0000e-04
# Epoch 8/250
# 169/169 [==============================] - ETA: 0s - loss: -0.6122 - dice_coef: 0.6125 - binary_accuracy: 0.9995
# Epoch 8: val_dice_coef did not improve from 0.62904
# 169/169 [==============================] - 52s 310ms/step - loss: -0.6122 - dice_coef: 0.6125 - binary_accuracy: 0.9995 - val_loss: -0.5485 - val_dice_coef: 0.5538 - val_binary_accuracy: 0.9992 - lr: 2.0000e-04
# Epoch 9/250
# 169/169 [==============================] - ETA: 0s - loss: -0.6192 - dice_coef: 0.6196 - binary_accuracy: 0.9995
# Epoch 9: val_dice_coef did not improve from 0.62904
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00013999999646330252.
# 169/169 [==============================] - 52s 309ms/step - loss: -0.6192 - dice_coef: 0.6196 - binary_accuracy: 0.9995 - val_loss: -0.5882 - val_dice_coef: 0.5949 - val_binary_accuracy: 0.9993 - lr: 2.0000e-04
# Epoch 10/250
# 169/169 [==============================] - ETA: 0s - loss: -0.6660 - dice_coef: 0.6663 - binary_accuracy: 0.9995
# Epoch 10: val_dice_coef improved from 0.62904 to 0.67696, saving model to checkpoint-010-0.677.hdf5
# 169/169 [==============================] - 53s 312ms/step - loss: -0.6660 - dice_coef: 0.6663 - binary_accuracy: 0.9995 - val_loss: -0.6727 - val_dice_coef: 0.6770 - val_binary_accuracy: 0.9995 - lr: 1.4000e-04
# Epoch 11/250
# 169/169 [==============================] - ETA: 0s - loss: -0.6779 - dice_coef: 0.6782 - binary_accuracy: 0.9996
# Epoch 11: val_dice_coef improved from 0.67696 to 0.68142, saving model to checkpoint-011-0.681.hdf5
# 169/169 [==============================] - 52s 311ms/step - loss: -0.6779 - dice_coef: 0.6782 - binary_accuracy: 0.9996 - val_loss: -0.6763 - val_dice_coef: 0.6814 - val_binary_accuracy: 0.9995 - lr: 1.4000e-04
# Epoch 12/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7012 - dice_coef: 0.7012 - binary_accuracy: 0.9996
# Epoch 12: val_dice_coef did not improve from 0.68142
# 169/169 [==============================] - 52s 311ms/step - loss: -0.7012 - dice_coef: 0.7012 - binary_accuracy: 0.9996 - val_loss: -0.6620 - val_dice_coef: 0.6668 - val_binary_accuracy: 0.9996 - lr: 1.4000e-04
# Epoch 13/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7086 - dice_coef: 0.7088 - binary_accuracy: 0.9996
# Epoch 13: val_dice_coef improved from 0.68142 to 0.71436, saving model to checkpoint-013-0.714.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.7086 - dice_coef: 0.7088 - binary_accuracy: 0.9996 - val_loss: -0.7113 - val_dice_coef: 0.7144 - val_binary_accuracy: 0.9997 - lr: 1.4000e-04
# Epoch 14/250
# 169/169 [==============================] - ETA: 0s - loss: -0.6709 - dice_coef: 0.6710 - binary_accuracy: 0.9995
# Epoch 14: val_dice_coef did not improve from 0.71436
# 169/169 [==============================] - 53s 311ms/step - loss: -0.6709 - dice_coef: 0.6710 - binary_accuracy: 0.9995 - val_loss: -0.7047 - val_dice_coef: 0.7086 - val_binary_accuracy: 0.9996 - lr: 1.4000e-04
# Epoch 15/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7052 - dice_coef: 0.7055 - binary_accuracy: 0.9996
# Epoch 15: val_dice_coef did not improve from 0.71436
# 169/169 [==============================] - 52s 310ms/step - loss: -0.7052 - dice_coef: 0.7055 - binary_accuracy: 0.9996 - val_loss: -0.6996 - val_dice_coef: 0.7058 - val_binary_accuracy: 0.9996 - lr: 1.4000e-04
# Epoch 16/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7306 - dice_coef: 0.7307 - binary_accuracy: 0.9996
# Epoch 16: val_dice_coef improved from 0.71436 to 0.74022, saving model to checkpoint-016-0.740.hdf5
# 169/169 [==============================] - 53s 312ms/step - loss: -0.7306 - dice_coef: 0.7307 - binary_accuracy: 0.9996 - val_loss: -0.7359 - val_dice_coef: 0.7402 - val_binary_accuracy: 0.9997 - lr: 1.4000e-04
# Epoch 17/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7263 - dice_coef: 0.7261 - binary_accuracy: 0.9996
# Epoch 17: val_dice_coef did not improve from 0.74022
# 169/169 [==============================] - 53s 312ms/step - loss: -0.7263 - dice_coef: 0.7261 - binary_accuracy: 0.9996 - val_loss: -0.7136 - val_dice_coef: 0.7174 - val_binary_accuracy: 0.9996 - lr: 1.4000e-04
# Epoch 18/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7412 - dice_coef: 0.7414 - binary_accuracy: 0.9996
# Epoch 18: val_dice_coef improved from 0.74022 to 0.74876, saving model to checkpoint-018-0.749.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.7412 - dice_coef: 0.7414 - binary_accuracy: 0.9996 - val_loss: -0.7462 - val_dice_coef: 0.7488 - val_binary_accuracy: 0.9997 - lr: 1.4000e-04
# Epoch 19/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7619 - dice_coef: 0.7622 - binary_accuracy: 0.9997
# Epoch 19: val_dice_coef improved from 0.74876 to 0.75829, saving model to checkpoint-019-0.758.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.7619 - dice_coef: 0.7622 - binary_accuracy: 0.9997 - val_loss: -0.7543 - val_dice_coef: 0.7583 - val_binary_accuracy: 0.9997 - lr: 1.4000e-04
# Epoch 20/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7473 - dice_coef: 0.7475 - binary_accuracy: 0.9997
# Epoch 20: val_dice_coef did not improve from 0.75829
# 169/169 [==============================] - 53s 312ms/step - loss: -0.7473 - dice_coef: 0.7475 - binary_accuracy: 0.9997 - val_loss: -0.7317 - val_dice_coef: 0.7361 - val_binary_accuracy: 0.9997 - lr: 1.4000e-04
# Epoch 21/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7570 - dice_coef: 0.7571 - binary_accuracy: 0.9997
# Epoch 21: val_dice_coef did not improve from 0.75829
# 169/169 [==============================] - 52s 311ms/step - loss: -0.7570 - dice_coef: 0.7571 - binary_accuracy: 0.9997 - val_loss: -0.7441 - val_dice_coef: 0.7478 - val_binary_accuracy: 0.9996 - lr: 1.4000e-04
# Epoch 22/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7689 - dice_coef: 0.7688 - binary_accuracy: 0.9997
# Epoch 22: val_dice_coef improved from 0.75829 to 0.75970, saving model to checkpoint-022-0.760.hdf5
# 169/169 [==============================] - 52s 310ms/step - loss: -0.7689 - dice_coef: 0.7688 - binary_accuracy: 0.9997 - val_loss: -0.7569 - val_dice_coef: 0.7597 - val_binary_accuracy: 0.9997 - lr: 1.4000e-04
# Epoch 23/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7632 - dice_coef: 0.7636 - binary_accuracy: 0.9997
# Epoch 23: val_dice_coef improved from 0.75970 to 0.76551, saving model to checkpoint-023-0.766.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.7632 - dice_coef: 0.7636 - binary_accuracy: 0.9997 - val_loss: -0.7618 - val_dice_coef: 0.7655 - val_binary_accuracy: 0.9997 - lr: 1.4000e-04
# Epoch 24/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7860 - dice_coef: 0.7858 - binary_accuracy: 0.9997
# Epoch 24: val_dice_coef improved from 0.76551 to 0.78084, saving model to checkpoint-024-0.781.hdf5
# 169/169 [==============================] - 53s 312ms/step - loss: -0.7860 - dice_coef: 0.7858 - binary_accuracy: 0.9997 - val_loss: -0.7778 - val_dice_coef: 0.7808 - val_binary_accuracy: 0.9997 - lr: 1.4000e-04
# Epoch 25/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7876 - dice_coef: 0.7878 - binary_accuracy: 0.9997
# Epoch 25: val_dice_coef did not improve from 0.78084
# 169/169 [==============================] - 52s 310ms/step - loss: -0.7876 - dice_coef: 0.7878 - binary_accuracy: 0.9997 - val_loss: -0.7361 - val_dice_coef: 0.7395 - val_binary_accuracy: 0.9996 - lr: 1.4000e-04
# Epoch 26/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7801 - dice_coef: 0.7801 - binary_accuracy: 0.9997
# Epoch 26: val_dice_coef did not improve from 0.78084
# 169/169 [==============================] - 52s 310ms/step - loss: -0.7801 - dice_coef: 0.7801 - binary_accuracy: 0.9997 - val_loss: -0.7694 - val_dice_coef: 0.7735 - val_binary_accuracy: 0.9997 - lr: 1.4000e-04
# Epoch 27/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7903 - dice_coef: 0.7905 - binary_accuracy: 0.9997
# Epoch 27: val_dice_coef did not improve from 0.78084
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 9.799999243114143e-05.
# 169/169 [==============================] - 53s 312ms/step - loss: -0.7903 - dice_coef: 0.7905 - binary_accuracy: 0.9997 - val_loss: -0.7577 - val_dice_coef: 0.7606 - val_binary_accuracy: 0.9997 - lr: 1.4000e-04
# Epoch 28/250
# 169/169 [==============================] - ETA: 0s - loss: -0.7943 - dice_coef: 0.7944 - binary_accuracy: 0.9997
# Epoch 28: val_dice_coef improved from 0.78084 to 0.80504, saving model to checkpoint-028-0.805.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.7943 - dice_coef: 0.7944 - binary_accuracy: 0.9997 - val_loss: -0.8016 - val_dice_coef: 0.8050 - val_binary_accuracy: 0.9998 - lr: 9.8000e-05
# Epoch 29/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8123 - dice_coef: 0.8125 - binary_accuracy: 0.9997
# Epoch 29: val_dice_coef improved from 0.80504 to 0.81325, saving model to checkpoint-029-0.813.hdf5
# 169/169 [==============================] - 52s 311ms/step - loss: -0.8123 - dice_coef: 0.8125 - binary_accuracy: 0.9997 - val_loss: -0.8093 - val_dice_coef: 0.8132 - val_binary_accuracy: 0.9997 - lr: 9.8000e-05
# Epoch 30/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8171 - dice_coef: 0.8173 - binary_accuracy: 0.9997
# Epoch 30: val_dice_coef did not improve from 0.81325
# 169/169 [==============================] - 53s 314ms/step - loss: -0.8171 - dice_coef: 0.8173 - binary_accuracy: 0.9997 - val_loss: -0.8088 - val_dice_coef: 0.8119 - val_binary_accuracy: 0.9998 - lr: 9.8000e-05
# Epoch 31/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8210 - dice_coef: 0.8211 - binary_accuracy: 0.9998
# Epoch 31: val_dice_coef did not improve from 0.81325
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8210 - dice_coef: 0.8211 - binary_accuracy: 0.9998 - val_loss: -0.7864 - val_dice_coef: 0.7886 - val_binary_accuracy: 0.9997 - lr: 9.8000e-05
# Epoch 32/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8068 - dice_coef: 0.8069 - binary_accuracy: 0.9997
# Epoch 32: val_dice_coef improved from 0.81325 to 0.81726, saving model to checkpoint-032-0.817.hdf5
# 169/169 [==============================] - 53s 313ms/step - loss: -0.8068 - dice_coef: 0.8069 - binary_accuracy: 0.9997 - val_loss: -0.8138 - val_dice_coef: 0.8173 - val_binary_accuracy: 0.9998 - lr: 9.8000e-05
# Epoch 33/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8261 - dice_coef: 0.8260 - binary_accuracy: 0.9998
# Epoch 33: val_dice_coef improved from 0.81726 to 0.82416, saving model to checkpoint-033-0.824.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.8261 - dice_coef: 0.8260 - binary_accuracy: 0.9998 - val_loss: -0.8202 - val_dice_coef: 0.8242 - val_binary_accuracy: 0.9998 - lr: 9.8000e-05
# Epoch 34/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8181 - dice_coef: 0.8183 - binary_accuracy: 0.9998
# Epoch 34: val_dice_coef did not improve from 0.82416
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8181 - dice_coef: 0.8183 - binary_accuracy: 0.9998 - val_loss: -0.8121 - val_dice_coef: 0.8147 - val_binary_accuracy: 0.9998 - lr: 9.8000e-05
# Epoch 35/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8268 - dice_coef: 0.8267 - binary_accuracy: 0.9998
# Epoch 35: val_dice_coef did not improve from 0.82416
# 169/169 [==============================] - 53s 312ms/step - loss: -0.8268 - dice_coef: 0.8267 - binary_accuracy: 0.9998 - val_loss: -0.8128 - val_dice_coef: 0.8160 - val_binary_accuracy: 0.9998 - lr: 9.8000e-05
# Epoch 36/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8264 - dice_coef: 0.8266 - binary_accuracy: 0.9998
# Epoch 36: val_dice_coef did not improve from 0.82416
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.859999266453087e-05.
# 169/169 [==============================] - 52s 311ms/step - loss: -0.8264 - dice_coef: 0.8266 - binary_accuracy: 0.9998 - val_loss: -0.8031 - val_dice_coef: 0.8066 - val_binary_accuracy: 0.9997 - lr: 9.8000e-05
# Epoch 37/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8329 - dice_coef: 0.8331 - binary_accuracy: 0.9998
# Epoch 37: val_dice_coef improved from 0.82416 to 0.82889, saving model to checkpoint-037-0.829.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.8329 - dice_coef: 0.8331 - binary_accuracy: 0.9998 - val_loss: -0.8254 - val_dice_coef: 0.8289 - val_binary_accuracy: 0.9998 - lr: 6.8600e-05
# Epoch 38/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8321 - dice_coef: 0.8321 - binary_accuracy: 0.9998
# Epoch 38: val_dice_coef did not improve from 0.82889
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8321 - dice_coef: 0.8321 - binary_accuracy: 0.9998 - val_loss: -0.8197 - val_dice_coef: 0.8221 - val_binary_accuracy: 0.9998 - lr: 6.8600e-05
# Epoch 39/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8369 - dice_coef: 0.8372 - binary_accuracy: 0.9998
# Epoch 39: val_dice_coef did not improve from 0.82889
# 169/169 [==============================] - 53s 312ms/step - loss: -0.8369 - dice_coef: 0.8372 - binary_accuracy: 0.9998 - val_loss: -0.8220 - val_dice_coef: 0.8240 - val_binary_accuracy: 0.9998 - lr: 6.8600e-05
# Epoch 40/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8372 - dice_coef: 0.8374 - binary_accuracy: 0.9998
# Epoch 40: val_dice_coef improved from 0.82889 to 0.83063, saving model to checkpoint-040-0.831.hdf5
# 169/169 [==============================] - 53s 312ms/step - loss: -0.8372 - dice_coef: 0.8374 - binary_accuracy: 0.9998 - val_loss: -0.8276 - val_dice_coef: 0.8306 - val_binary_accuracy: 0.9998 - lr: 6.8600e-05
# Epoch 41/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8450 - dice_coef: 0.8451 - binary_accuracy: 0.9998
# Epoch 41: val_dice_coef did not improve from 0.83063
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8450 - dice_coef: 0.8451 - binary_accuracy: 0.9998 - val_loss: -0.8252 - val_dice_coef: 0.8278 - val_binary_accuracy: 0.9998 - lr: 6.8600e-05
# Epoch 42/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8449 - dice_coef: 0.8450 - binary_accuracy: 0.9998
# Epoch 42: val_dice_coef did not improve from 0.83063
# 169/169 [==============================] - 53s 312ms/step - loss: -0.8449 - dice_coef: 0.8450 - binary_accuracy: 0.9998 - val_loss: -0.8276 - val_dice_coef: 0.8302 - val_binary_accuracy: 0.9998 - lr: 6.8600e-05
# Epoch 43/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8492 - dice_coef: 0.8493 - binary_accuracy: 0.9998
# Epoch 43: val_dice_coef did not improve from 0.83063
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 4.801999384653754e-05.
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8492 - dice_coef: 0.8493 - binary_accuracy: 0.9998 - val_loss: -0.8254 - val_dice_coef: 0.8280 - val_binary_accuracy: 0.9998 - lr: 6.8600e-05
# Epoch 44/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8461 - dice_coef: 0.8463 - binary_accuracy: 0.9998
# Epoch 44: val_dice_coef did not improve from 0.83063
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8461 - dice_coef: 0.8463 - binary_accuracy: 0.9998 - val_loss: -0.8215 - val_dice_coef: 0.8239 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 45/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8503 - dice_coef: 0.8504 - binary_accuracy: 0.9998
# Epoch 45: val_dice_coef improved from 0.83063 to 0.83118, saving model to checkpoint-045-0.831.hdf5
# 169/169 [==============================] - 53s 313ms/step - loss: -0.8503 - dice_coef: 0.8504 - binary_accuracy: 0.9998 - val_loss: -0.8286 - val_dice_coef: 0.8312 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 46/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8515 - dice_coef: 0.8512 - binary_accuracy: 0.9998
# Epoch 46: val_dice_coef improved from 0.83118 to 0.83194, saving model to checkpoint-046-0.832.hdf5
# 169/169 [==============================] - 52s 311ms/step - loss: -0.8515 - dice_coef: 0.8512 - binary_accuracy: 0.9998 - val_loss: -0.8294 - val_dice_coef: 0.8319 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 47/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8544 - dice_coef: 0.8545 - binary_accuracy: 0.9998
# Epoch 47: val_dice_coef improved from 0.83194 to 0.83231, saving model to checkpoint-047-0.832.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.8544 - dice_coef: 0.8545 - binary_accuracy: 0.9998 - val_loss: -0.8300 - val_dice_coef: 0.8323 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 48/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8556 - dice_coef: 0.8557 - binary_accuracy: 0.9998
# Epoch 48: val_dice_coef improved from 0.83231 to 0.83533, saving model to checkpoint-048-0.835.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.8556 - dice_coef: 0.8557 - binary_accuracy: 0.9998 - val_loss: -0.8324 - val_dice_coef: 0.8353 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 49/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8559 - dice_coef: 0.8561 - binary_accuracy: 0.9998
# Epoch 49: val_dice_coef did not improve from 0.83533
# 169/169 [==============================] - 53s 312ms/step - loss: -0.8559 - dice_coef: 0.8561 - binary_accuracy: 0.9998 - val_loss: -0.8321 - val_dice_coef: 0.8343 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 50/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8582 - dice_coef: 0.8583 - binary_accuracy: 0.9998
# Epoch 50: val_dice_coef improved from 0.83533 to 0.83558, saving model to checkpoint-050-0.836.hdf5
# 169/169 [==============================] - 52s 311ms/step - loss: -0.8582 - dice_coef: 0.8583 - binary_accuracy: 0.9998 - val_loss: -0.8332 - val_dice_coef: 0.8356 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 51/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8576 - dice_coef: 0.8578 - binary_accuracy: 0.9998
# Epoch 51: val_dice_coef did not improve from 0.83558
# 169/169 [==============================] - 52s 311ms/step - loss: -0.8576 - dice_coef: 0.8578 - binary_accuracy: 0.9998 - val_loss: -0.8328 - val_dice_coef: 0.8352 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 52/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8588 - dice_coef: 0.8587 - binary_accuracy: 0.9998
# Epoch 52: val_dice_coef did not improve from 0.83558
# 169/169 [==============================] - 53s 312ms/step - loss: -0.8588 - dice_coef: 0.8587 - binary_accuracy: 0.9998 - val_loss: -0.8325 - val_dice_coef: 0.8351 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 53/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8579 - dice_coef: 0.8578 - binary_accuracy: 0.9998
# Epoch 53: val_dice_coef improved from 0.83558 to 0.84189, saving model to checkpoint-053-0.842.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.8579 - dice_coef: 0.8578 - binary_accuracy: 0.9998 - val_loss: -0.8391 - val_dice_coef: 0.8419 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 54/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8633 - dice_coef: 0.8635 - binary_accuracy: 0.9998
# Epoch 54: val_dice_coef did not improve from 0.84189
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8633 - dice_coef: 0.8635 - binary_accuracy: 0.9998 - val_loss: -0.8363 - val_dice_coef: 0.8389 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 55/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8637 - dice_coef: 0.8638 - binary_accuracy: 0.9998
# Epoch 55: val_dice_coef did not improve from 0.84189
# 169/169 [==============================] - 53s 312ms/step - loss: -0.8637 - dice_coef: 0.8638 - binary_accuracy: 0.9998 - val_loss: -0.8380 - val_dice_coef: 0.8406 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 56/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8588 - dice_coef: 0.8591 - binary_accuracy: 0.9998
# Epoch 56: val_dice_coef improved from 0.84189 to 0.84253, saving model to checkpoint-056-0.843.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.8588 - dice_coef: 0.8591 - binary_accuracy: 0.9998 - val_loss: -0.8392 - val_dice_coef: 0.8425 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 57/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8670 - dice_coef: 0.8671 - binary_accuracy: 0.9998
# Epoch 57: val_dice_coef did not improve from 0.84253
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8670 - dice_coef: 0.8671 - binary_accuracy: 0.9998 - val_loss: -0.8359 - val_dice_coef: 0.8378 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 58/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8642 - dice_coef: 0.8644 - binary_accuracy: 0.9998
# Epoch 58: val_dice_coef did not improve from 0.84253
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8642 - dice_coef: 0.8644 - binary_accuracy: 0.9998 - val_loss: -0.8345 - val_dice_coef: 0.8364 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 59/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8680 - dice_coef: 0.8680 - binary_accuracy: 0.9998
# Epoch 59: val_dice_coef did not improve from 0.84253
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 3.3613994673942216e-05.
# 169/169 [==============================] - 53s 315ms/step - loss: -0.8680 - dice_coef: 0.8680 - binary_accuracy: 0.9998 - val_loss: -0.8371 - val_dice_coef: 0.8392 - val_binary_accuracy: 0.9998 - lr: 4.8020e-05
# Epoch 60/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8688 - dice_coef: 0.8689 - binary_accuracy: 0.9998
# Epoch 60: val_dice_coef did not improve from 0.84253
# 169/169 [==============================] - 53s 312ms/step - loss: -0.8688 - dice_coef: 0.8689 - binary_accuracy: 0.9998 - val_loss: -0.8379 - val_dice_coef: 0.8400 - val_binary_accuracy: 0.9998 - lr: 3.3614e-05
# Epoch 61/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8684 - dice_coef: 0.8685 - binary_accuracy: 0.9998
# Epoch 61: val_dice_coef improved from 0.84253 to 0.84505, saving model to checkpoint-061-0.845.hdf5
# 169/169 [==============================] - 53s 312ms/step - loss: -0.8684 - dice_coef: 0.8685 - binary_accuracy: 0.9998 - val_loss: -0.8424 - val_dice_coef: 0.8450 - val_binary_accuracy: 0.9998 - lr: 3.3614e-05
# Epoch 62/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8729 - dice_coef: 0.8730 - binary_accuracy: 0.9998
# Epoch 62: val_dice_coef improved from 0.84505 to 0.84589, saving model to checkpoint-062-0.846.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.8729 - dice_coef: 0.8730 - binary_accuracy: 0.9998 - val_loss: -0.8434 - val_dice_coef: 0.8459 - val_binary_accuracy: 0.9998 - lr: 3.3614e-05
# Epoch 63/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8769 - dice_coef: 0.8770 - binary_accuracy: 0.9998
# Epoch 63: val_dice_coef did not improve from 0.84589
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8769 - dice_coef: 0.8770 - binary_accuracy: 0.9998 - val_loss: -0.8428 - val_dice_coef: 0.8450 - val_binary_accuracy: 0.9998 - lr: 3.3614e-05
# Epoch 64/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8731 - dice_coef: 0.8729 - binary_accuracy: 0.9998
# Epoch 64: val_dice_coef did not improve from 0.84589
# 169/169 [==============================] - 53s 313ms/step - loss: -0.8731 - dice_coef: 0.8729 - binary_accuracy: 0.9998 - val_loss: -0.8413 - val_dice_coef: 0.8434 - val_binary_accuracy: 0.9998 - lr: 3.3614e-05
# Epoch 65/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8777 - dice_coef: 0.8777 - binary_accuracy: 0.9998
# Epoch 65: val_dice_coef did not improve from 0.84589
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 2.3529794998466968e-05.
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8777 - dice_coef: 0.8777 - binary_accuracy: 0.9998 - val_loss: -0.8432 - val_dice_coef: 0.8454 - val_binary_accuracy: 0.9998 - lr: 3.3614e-05
# Epoch 66/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8752 - dice_coef: 0.8752 - binary_accuracy: 0.9998
# Epoch 66: val_dice_coef did not improve from 0.84589
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8752 - dice_coef: 0.8752 - binary_accuracy: 0.9998 - val_loss: -0.8416 - val_dice_coef: 0.8435 - val_binary_accuracy: 0.9998 - lr: 2.3530e-05
# Epoch 67/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8808 - dice_coef: 0.8809 - binary_accuracy: 0.9998
# Epoch 67: val_dice_coef did not improve from 0.84589
# 169/169 [==============================] - 53s 312ms/step - loss: -0.8808 - dice_coef: 0.8809 - binary_accuracy: 0.9998 - val_loss: -0.8430 - val_dice_coef: 0.8448 - val_binary_accuracy: 0.9998 - lr: 2.3530e-05
# Epoch 68/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8791 - dice_coef: 0.8792 - binary_accuracy: 0.9998
# Epoch 68: val_dice_coef did not improve from 0.84589
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.6470857008243908e-05.
# 169/169 [==============================] - 53s 311ms/step - loss: -0.8791 - dice_coef: 0.8792 - binary_accuracy: 0.9998 - val_loss: -0.8425 - val_dice_coef: 0.8445 - val_binary_accuracy: 0.9998 - lr: 2.3530e-05
# Epoch 69/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8793 - dice_coef: 0.8794 - binary_accuracy: 0.9998
# Epoch 69: val_dice_coef improved from 0.84589 to 0.84696, saving model to checkpoint-069-0.847.hdf5
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8793 - dice_coef: 0.8794 - binary_accuracy: 0.9998 - val_loss: -0.8447 - val_dice_coef: 0.8470 - val_binary_accuracy: 0.9998 - lr: 1.6471e-05
# Epoch 70/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8826 - dice_coef: 0.8827 - binary_accuracy: 0.9998
# Epoch 70: val_dice_coef improved from 0.84696 to 0.84841, saving model to checkpoint-070-0.848.hdf5
# 169/169 [==============================] - 53s 312ms/step - loss: -0.8826 - dice_coef: 0.8827 - binary_accuracy: 0.9998 - val_loss: -0.8461 - val_dice_coef: 0.8484 - val_binary_accuracy: 0.9998 - lr: 1.6471e-05
# Epoch 71/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8850 - dice_coef: 0.8851 - binary_accuracy: 0.9998
# Epoch 71: val_dice_coef did not improve from 0.84841
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8850 - dice_coef: 0.8851 - binary_accuracy: 0.9998 - val_loss: -0.8460 - val_dice_coef: 0.8480 - val_binary_accuracy: 0.9998 - lr: 1.6471e-05
# Epoch 72/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8836 - dice_coef: 0.8837 - binary_accuracy: 0.9998
# Epoch 72: val_dice_coef did not improve from 0.84841
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8836 - dice_coef: 0.8837 - binary_accuracy: 0.9998 - val_loss: -0.8449 - val_dice_coef: 0.8470 - val_binary_accuracy: 0.9998 - lr: 1.6471e-05
# Epoch 73/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8839 - dice_coef: 0.8839 - binary_accuracy: 0.9998
# Epoch 73: val_dice_coef did not improve from 0.84841
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1.1529599396453704e-05.
# 169/169 [==============================] - 52s 311ms/step - loss: -0.8839 - dice_coef: 0.8839 - binary_accuracy: 0.9998 - val_loss: -0.8461 - val_dice_coef: 0.8481 - val_binary_accuracy: 0.9998 - lr: 1.6471e-05
# Epoch 74/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8853 - dice_coef: 0.8854 - binary_accuracy: 0.9998
# Epoch 74: val_dice_coef improved from 0.84841 to 0.84910, saving model to checkpoint-074-0.849.hdf5
# 169/169 [==============================] - 53s 314ms/step - loss: -0.8853 - dice_coef: 0.8854 - binary_accuracy: 0.9998 - val_loss: -0.8471 - val_dice_coef: 0.8491 - val_binary_accuracy: 0.9998 - lr: 1.1530e-05
# Epoch 75/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8833 - dice_coef: 0.8834 - binary_accuracy: 0.9998
# Epoch 75: val_dice_coef did not improve from 0.84910
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8833 - dice_coef: 0.8834 - binary_accuracy: 0.9998 - val_loss: -0.8470 - val_dice_coef: 0.8489 - val_binary_accuracy: 0.9998 - lr: 1.1530e-05
# Epoch 76/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8840 - dice_coef: 0.8840 - binary_accuracy: 0.9998
# Epoch 76: val_dice_coef improved from 0.84910 to 0.84962, saving model to checkpoint-076-0.850.hdf5
# 169/169 [==============================] - 52s 311ms/step - loss: -0.8840 - dice_coef: 0.8840 - binary_accuracy: 0.9998 - val_loss: -0.8476 - val_dice_coef: 0.8496 - val_binary_accuracy: 0.9998 - lr: 1.1530e-05
# Epoch 77/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8843 - dice_coef: 0.8844 - binary_accuracy: 0.9999
# Epoch 77: val_dice_coef did not improve from 0.84962
# 169/169 [==============================] - 53s 313ms/step - loss: -0.8843 - dice_coef: 0.8844 - binary_accuracy: 0.9999 - val_loss: -0.8465 - val_dice_coef: 0.8485 - val_binary_accuracy: 0.9998 - lr: 1.1530e-05
# Epoch 78/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8866 - dice_coef: 0.8868 - binary_accuracy: 0.9999
# Epoch 78: val_dice_coef improved from 0.84962 to 0.85014, saving model to checkpoint-078-0.850.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.8866 - dice_coef: 0.8868 - binary_accuracy: 0.9999 - val_loss: -0.8479 - val_dice_coef: 0.8501 - val_binary_accuracy: 0.9998 - lr: 1.1530e-05
# Epoch 79/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8853 - dice_coef: 0.8853 - binary_accuracy: 0.9999
# Epoch 79: val_dice_coef did not improve from 0.85014
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8853 - dice_coef: 0.8853 - binary_accuracy: 0.9999 - val_loss: -0.8473 - val_dice_coef: 0.8493 - val_binary_accuracy: 0.9998 - lr: 1.1530e-05
# Epoch 80/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8909 - dice_coef: 0.8910 - binary_accuracy: 0.9999
# Epoch 80: val_dice_coef improved from 0.85014 to 0.85053, saving model to checkpoint-080-0.851.hdf5
# 169/169 [==============================] - 53s 314ms/step - loss: -0.8909 - dice_coef: 0.8910 - binary_accuracy: 0.9999 - val_loss: -0.8483 - val_dice_coef: 0.8505 - val_binary_accuracy: 0.9998 - lr: 1.1530e-05
# Epoch 81/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8872 - dice_coef: 0.8873 - binary_accuracy: 0.9999
# Epoch 81: val_dice_coef did not improve from 0.85053
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8872 - dice_coef: 0.8873 - binary_accuracy: 0.9999 - val_loss: -0.8481 - val_dice_coef: 0.8501 - val_binary_accuracy: 0.9998 - lr: 1.1530e-05
# Epoch 82/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8898 - dice_coef: 0.8898 - binary_accuracy: 0.9999
# Epoch 82: val_dice_coef did not improve from 0.85053
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8898 - dice_coef: 0.8898 - binary_accuracy: 0.9999 - val_loss: -0.8471 - val_dice_coef: 0.8491 - val_binary_accuracy: 0.9998 - lr: 1.1530e-05
# Epoch 83/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8854 - dice_coef: 0.8855 - binary_accuracy: 0.9999
# Epoch 83: val_dice_coef did not improve from 0.85053
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 8.070719832176109e-06.
# 169/169 [==============================] - 52s 310ms/step - loss: -0.8854 - dice_coef: 0.8855 - binary_accuracy: 0.9999 - val_loss: -0.8481 - val_dice_coef: 0.8501 - val_binary_accuracy: 0.9998 - lr: 1.1530e-05
# Epoch 84/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8846 - dice_coef: 0.8846 - binary_accuracy: 0.9999
# Epoch 84: val_dice_coef improved from 0.85053 to 0.85054, saving model to checkpoint-084-0.851.hdf5
# 169/169 [==============================] - 53s 314ms/step - loss: -0.8846 - dice_coef: 0.8846 - binary_accuracy: 0.9999 - val_loss: -0.8485 - val_dice_coef: 0.8505 - val_binary_accuracy: 0.9998 - lr: 8.0707e-06
# Epoch 85/250
# 169/169 [==============================] - ETA: 0s - loss: -0.8880 - dice_coef: 0.8881 - binary_accuracy: 0.9999
# Epoch 85: val_dice_coef improved from 0.85054 to 0.85074, saving model to checkpoint-085-0.851.hdf5
# 169/169 [==============================] - 53s 311ms/step - loss: -0.8880 - dice_coef: 0.8881 - binary_accuracy: 0.9999 - val_loss: -0.8487 - val_dice_coef: 0.8507 - val_binary_accuracy: 0.9998 - lr: 8.0707e-06
# Epoch 86/250
# 113/169 [===================>..........] - ETA: 16s - loss: -0.8917 - dice_coef: 0.8917 - binary_accuracy: 0.9999
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f2dddeb93028> in <cell line: 2>()
#       1 # Train the model
# ----> 2 history = model.fit(trainX, trainY, batch_size=32, epochs=250, validation_data=(testX, testY), callbacks=callbacks)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Save training history
with open('LC_UNet_trainHistory.pkl', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %%
# Save the final model
model.save("LC_v4_UNet_cl.h5")

# %%
# Evaluate the model
loss, dice, accuracy = model.evaluate(testX, testY)
print(f"Loss: {loss}, Dice Coefficient: {dice}, Accuracy: {accuracy}")

# %%
# Predictions for metric calculations
predictions = model.predict(testX)
pred_binary = (predictions > 0.5).astype(np.float32)
y_true_flat = testY.flatten()
y_pred_flat = pred_binary.flatten()

# %%
precision = precision_score(y_true_flat, y_pred_flat)
recall = recall_score(y_true_flat, y_pred_flat)
f1 = f1_score(y_true_flat, y_pred_flat)

# %%
print(f"Precision: {precision}, Recall: {recall}, F1 Score: {f1}")

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title("Training and Validation Loss")

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history['dice_coef'], label='Dice Coefficient')
plt.plot(history.history['val_dice_coef'], label='Validation Dice Coefficient')
plt.legend()
plt.title("Training and Validation Dice Coefficient")
plt.show()
