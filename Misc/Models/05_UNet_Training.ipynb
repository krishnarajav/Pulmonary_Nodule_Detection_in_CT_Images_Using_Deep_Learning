# %% [markdown]
# Importing Modules

# %%
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt

# %% [markdown]
# Mounting Google Drive to access Training Data

# %%
from google.colab import drive
drive.mount("drive")
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %% [markdown]
# Loading train & test data into memory

# %%
trainX = np.load("drive/MyDrive/Datasets/lc/v4/trainX.npy").astype(np.float32)
trainY = np.load("drive/MyDrive/Datasets/lc/v4/trainY.npy").astype(np.float32)
testX = np.load("drive/MyDrive/Datasets/lc/v4/testX.npy").astype(np.float32)
testY = np.load("drive/MyDrive/Datasets/lc/v4/testY.npy").astype(np.float32)

# %%
# unique, counts = np.unique(trainY, return_counts=True)
# print(unique, counts)

# %% [markdown]
# Normalizing values

# %%
trainX = (trainX-127.0)/127.0
testX = (testX-127.0)/127.0
trainY = (trainY>127).astype(np.float32)
testY = (testY>127).astype(np.float32)

# %%
print(trainX.dtype)
print(trainY.dtype)
print(testX.dtype)
print(testY.dtype)
# Out:
# float32
# float32
# float32
# float32

# %% [markdown]
# Reshaping train & test data

# %%
trainX = np.reshape(trainX, (len(trainX), 512, 512, 1))
trainY = np.reshape(trainY, (len(trainY), 512, 512, 1))
testX = np.reshape(testX, (len(testX), 512, 512, 1))
testY = np.reshape(testY, (len(testY), 512, 512, 1))

print("trainX:",trainX.shape)
print("trainY:",trainY.shape)
print("testX:",testX.shape)
print("testY:",testY.shape)
# Out:
# trainX: (1349, 512, 512, 1)
# trainY: (1349, 512, 512, 1)
# testX: (8, 512, 512, 1)
# testY: (8, 512, 512, 1)

# %% [markdown]
# Evaluation Metrics for U-Net model

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %% [markdown]
# Defining U-Net model architecture

# %%
def unet(input_size=(512,512,1)):
    inputs = Input(input_size)
    K.set_image_data_format('channels_last')

    #Encoder
    conv1 = Conv2D(32, (3,3), activation="relu", padding="same")(inputs)
    conv1 = Conv2D(32, (3,3), activation="relu", padding="same")(conv1)
    pool1 = MaxPooling2D(pool_size=(2,2))(conv1)

    conv2 = Conv2D(64, (3,3), activation="relu", padding="same")(pool1)
    conv2 = Conv2D(64, (3,3), activation="relu", padding="same")(conv2)
    pool2 = MaxPooling2D(pool_size=(2,2))(conv2)

    conv3 = Conv2D(128, (3,3), activation="relu", padding="same")(pool2)
    conv3 = Conv2D(128, (3,3), activation="relu", padding="same")(conv3)
    pool3 = MaxPooling2D(pool_size=(2,2))(conv3)

    conv4 = Conv2D(256, (3,3), activation="relu", padding="same")(pool3)
    conv4 = Conv2D(256, (3,3), activation="relu", padding="same")(conv4)
    pool4 = MaxPooling2D(pool_size=(2,2))(conv4)

    #BottleNeck
    conv5 = Conv2D(512, (3,3), activation="relu", padding="same")(pool4)
    conv5 = Conv2D(512, (3,3), activation="relu", padding="same")(conv5)

    #Decoder
    up6 = concatenate([Conv2DTranspose(256, kernel_size=(2,2), strides=(2,2), padding="same")(conv5), conv4], axis=-1)
    conv6 = Conv2D(256, (3,3), activation="relu", padding="same")(up6)
    conv6 = Conv2D(256, (3,3), activation="relu", padding="same")(conv6)

    up7 = concatenate([Conv2DTranspose(128, kernel_size=(2,2), strides=(2,2), padding="same")(conv6), conv3], axis=-1)
    conv7 = Conv2D(128, (3,3), activation="relu", padding="same")(up7)
    conv7 = Conv2D(128, (3,3), activation="relu", padding="same")(conv7)

    up8 = concatenate([Conv2DTranspose(64, kernel_size=(2,2), strides=(2,2), padding="same")(conv7), conv2], axis=-1)
    conv8 = Conv2D(64, (3,3), activation="relu", padding="same")(up8)
    conv8 = Conv2D(64, (3,3), activation="relu", padding="same")(conv8)

    up9 = concatenate([Conv2DTranspose(32, kernel_size=(2,2), strides=(2,2), padding="same")(conv8), conv1], axis=-1)
    conv9 = Conv2D(32, (3,3), activation="relu", padding="same")(up9)
    conv9 = Conv2D(32, (3,3), activation="relu", padding="same")(conv9)

    conv10 = Conv2D(1, (1,1), activation="sigmoid")(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %% [markdown]
# Connecting to TPU cluster system for faster training

# %%
#Get a handle to the attached TPU. On GCP it will be the CloudTPU itself
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()
#Connect to the TPU handle and initialise it
tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)

strategy = tf.distribute.experimental.TPUStrategy(resolver)
# Out:
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.

# %% [markdown]
# Callback functions for U-Net model training

# %%
weight_path="checkpoint-{epoch:03d}-{val_dice_coef:.3f}.hdf5"

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.7,
                                   patience=3,
                                   verbose=1, mode='min', min_delta=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_loss",
                      mode="min",
                      patience=30)

CALLBACKS = [checkpoint, early, reduceLROnPlat]

# %% [markdown]
# Creating U-Net model

# %%
with strategy.scope():
  model = unet(input_size=(512,512,1))
  model.compile(optimizer=Adam(learning_rate=2e-4),
              loss=[dice_coef_loss],
              metrics = [dice_coef, 'binary_accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 1)]        0         []
#
#  conv2d (Conv2D)             (None, 512, 512, 32)         320       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 512, 512, 32)         9248      ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 256, 256, 32)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 64)         18496     ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 64)         36928     ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 128, 128, 64)         0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 128)        73856     ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 128)        147584    ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 64, 128)          0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 256)          295168    ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 256)          590080    ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 32, 32, 256)          0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 512)          1180160   ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 512)          2359808   ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 64, 64, 256)          524544    ['conv2d_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 64, 64, 512)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 256)          1179904   ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 64, 64, 256)          590080    ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 128, 128, 128)        131200    ['conv2d_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 128, 128, 256)        0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 128, 128, 128)        295040    ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 128)        147584    ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 256, 256, 64)         32832     ['conv2d_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 256, 256, 128)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 256, 256, 64)         73792     ['concatenate_2[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 256, 256, 64)         36928     ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 512, 512, 32)         8224      ['conv2d_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 512, 512, 64)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 512, 512, 32)         18464     ['concatenate_3[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 512, 512, 32)         9248      ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 512, 512, 1)          33        ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 7759521 (29.60 MB)
# Trainable params: 7759521 (29.60 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# Train model

# %%
history = model.fit(x = trainX,
                    y = trainY,
                    batch_size = 32,
                    epochs = 250,
                    validation_data =(testX,testY),
                    callbacks=CALLBACKS
                  )
# Out:
# Epoch 1/250
# 43/43 [==============================] - ETA: 0s - loss: -0.0070 - dice_coef: 0.0157 - binary_accuracy: 0.9921
# Epoch 1: val_loss improved from inf to -0.04312, saving model to checkpoint-001-0.064.hdf5
# 43/43 [==============================] - 101s 2s/step - loss: -0.0070 - dice_coef: 0.0157 - binary_accuracy: 0.9921 - val_loss: -0.0431 - val_dice_coef: 0.0644 - val_binary_accuracy: 0.9989 - lr: 2.0000e-04
# Epoch 2/250
# 43/43 [==============================] - ETA: 0s - loss: -0.0988 - dice_coef: 0.1070 - binary_accuracy: 0.9970
# Epoch 2: val_loss improved from -0.04312 to -0.17507, saving model to checkpoint-002-0.192.hdf5
# 43/43 [==============================] - 11s 266ms/step - loss: -0.0988 - dice_coef: 0.1070 - binary_accuracy: 0.9970 - val_loss: -0.1751 - val_dice_coef: 0.1920 - val_binary_accuracy: 0.9979 - lr: 2.0000e-04
# Epoch 3/250
# 43/43 [==============================] - ETA: 0s - loss: -0.2435 - dice_coef: 0.2490 - binary_accuracy: 0.9985
# Epoch 3: val_loss improved from -0.17507 to -0.32347, saving model to checkpoint-003-0.338.hdf5
# 43/43 [==============================] - 11s 265ms/step - loss: -0.2435 - dice_coef: 0.2490 - binary_accuracy: 0.9985 - val_loss: -0.3235 - val_dice_coef: 0.3375 - val_binary_accuracy: 0.9990 - lr: 2.0000e-04
# Epoch 4/250
# 43/43 [==============================] - ETA: 0s - loss: -0.3740 - dice_coef: 0.3772 - binary_accuracy: 0.9990
# Epoch 4: val_loss improved from -0.32347 to -0.36180, saving model to checkpoint-004-0.377.hdf5
# 43/43 [==============================] - 12s 283ms/step - loss: -0.3740 - dice_coef: 0.3772 - binary_accuracy: 0.9990 - val_loss: -0.3618 - val_dice_coef: 0.3771 - val_binary_accuracy: 0.9992 - lr: 2.0000e-04
# Epoch 5/250
# 43/43 [==============================] - ETA: 0s - loss: -0.4142 - dice_coef: 0.4181 - binary_accuracy: 0.9990
# Epoch 5: val_loss did not improve from -0.36180
# 43/43 [==============================] - 11s 264ms/step - loss: -0.4142 - dice_coef: 0.4181 - binary_accuracy: 0.9990 - val_loss: -0.2836 - val_dice_coef: 0.2995 - val_binary_accuracy: 0.9976 - lr: 2.0000e-04
# Epoch 6/250
# 43/43 [==============================] - ETA: 0s - loss: -0.4280 - dice_coef: 0.4326 - binary_accuracy: 0.9992
# Epoch 6: val_loss improved from -0.36180 to -0.41056, saving model to checkpoint-006-0.424.hdf5
# 43/43 [==============================] - 11s 266ms/step - loss: -0.4280 - dice_coef: 0.4326 - binary_accuracy: 0.9992 - val_loss: -0.4106 - val_dice_coef: 0.4239 - val_binary_accuracy: 0.9989 - lr: 2.0000e-04
# Epoch 7/250
# 43/43 [==============================] - ETA: 0s - loss: -0.4856 - dice_coef: 0.4866 - binary_accuracy: 0.9993
# Epoch 7: val_loss improved from -0.41056 to -0.42702, saving model to checkpoint-007-0.440.hdf5
# 43/43 [==============================] - 12s 270ms/step - loss: -0.4856 - dice_coef: 0.4866 - binary_accuracy: 0.9993 - val_loss: -0.4270 - val_dice_coef: 0.4397 - val_binary_accuracy: 0.9989 - lr: 2.0000e-04
# Epoch 8/250
# 43/43 [==============================] - ETA: 0s - loss: -0.5053 - dice_coef: 0.5042 - binary_accuracy: 0.9993
# Epoch 8: val_loss did not improve from -0.42702
# 43/43 [==============================] - 11s 263ms/step - loss: -0.5053 - dice_coef: 0.5042 - binary_accuracy: 0.9993 - val_loss: -0.3947 - val_dice_coef: 0.4076 - val_binary_accuracy: 0.9988 - lr: 2.0000e-04
# Epoch 9/250
# 43/43 [==============================] - ETA: 0s - loss: -0.5118 - dice_coef: 0.5166 - binary_accuracy: 0.9994
# Epoch 9: val_loss improved from -0.42702 to -0.48201, saving model to checkpoint-009-0.494.hdf5
# 43/43 [==============================] - 11s 266ms/step - loss: -0.5118 - dice_coef: 0.5166 - binary_accuracy: 0.9994 - val_loss: -0.4820 - val_dice_coef: 0.4941 - val_binary_accuracy: 0.9993 - lr: 2.0000e-04
# Epoch 10/250
# 43/43 [==============================] - ETA: 0s - loss: -0.5346 - dice_coef: 0.5350 - binary_accuracy: 0.9994
# Epoch 10: val_loss did not improve from -0.48201
# 43/43 [==============================] - 11s 266ms/step - loss: -0.5346 - dice_coef: 0.5350 - binary_accuracy: 0.9994 - val_loss: -0.3343 - val_dice_coef: 0.3503 - val_binary_accuracy: 0.9993 - lr: 2.0000e-04
# Epoch 11/250
# 43/43 [==============================] - ETA: 0s - loss: -0.5262 - dice_coef: 0.5284 - binary_accuracy: 0.9994
# Epoch 11: val_loss did not improve from -0.48201
# 43/43 [==============================] - 11s 263ms/step - loss: -0.5262 - dice_coef: 0.5284 - binary_accuracy: 0.9994 - val_loss: -0.4161 - val_dice_coef: 0.4281 - val_binary_accuracy: 0.9987 - lr: 2.0000e-04
# Epoch 12/250
# 43/43 [==============================] - ETA: 0s - loss: -0.5375 - dice_coef: 0.5397 - binary_accuracy: 0.9994
# Epoch 12: val_loss improved from -0.48201 to -0.49830, saving model to checkpoint-012-0.509.hdf5
# 43/43 [==============================] - 11s 266ms/step - loss: -0.5375 - dice_coef: 0.5397 - binary_accuracy: 0.9994 - val_loss: -0.4983 - val_dice_coef: 0.5089 - val_binary_accuracy: 0.9991 - lr: 2.0000e-04
# Epoch 13/250
# 43/43 [==============================] - ETA: 0s - loss: -0.5977 - dice_coef: 0.5965 - binary_accuracy: 0.9995
# Epoch 13: val_loss improved from -0.49830 to -0.55703, saving model to checkpoint-013-0.567.hdf5
# 43/43 [==============================] - 11s 268ms/step - loss: -0.5977 - dice_coef: 0.5965 - binary_accuracy: 0.9995 - val_loss: -0.5570 - val_dice_coef: 0.5672 - val_binary_accuracy: 0.9994 - lr: 2.0000e-04
# Epoch 14/250
# 43/43 [==============================] - ETA: 0s - loss: -0.5459 - dice_coef: 0.5497 - binary_accuracy: 0.9992
# Epoch 14: val_loss did not improve from -0.55703
# 43/43 [==============================] - 11s 268ms/step - loss: -0.5459 - dice_coef: 0.5497 - binary_accuracy: 0.9992 - val_loss: -0.5034 - val_dice_coef: 0.5155 - val_binary_accuracy: 0.9994 - lr: 2.0000e-04
# Epoch 15/250
# 43/43 [==============================] - ETA: 0s - loss: -0.5839 - dice_coef: 0.5874 - binary_accuracy: 0.9994
# Epoch 15: val_loss did not improve from -0.55703
# 43/43 [==============================] - 11s 264ms/step - loss: -0.5839 - dice_coef: 0.5874 - binary_accuracy: 0.9994 - val_loss: -0.5331 - val_dice_coef: 0.5439 - val_binary_accuracy: 0.9994 - lr: 2.0000e-04
# Epoch 16/250
# 43/43 [==============================] - ETA: 0s - loss: -0.5994 - dice_coef: 0.6029 - binary_accuracy: 0.9995
# Epoch 16: val_loss did not improve from -0.55703
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00013999999646330252.
# 43/43 [==============================] - 11s 265ms/step - loss: -0.5994 - dice_coef: 0.6029 - binary_accuracy: 0.9995 - val_loss: -0.4695 - val_dice_coef: 0.4807 - val_binary_accuracy: 0.9994 - lr: 2.0000e-04
# Epoch 17/250
# 43/43 [==============================] - ETA: 0s - loss: -0.5790 - dice_coef: 0.5836 - binary_accuracy: 0.9994
# Epoch 17: val_loss did not improve from -0.55703
# 43/43 [==============================] - 12s 269ms/step - loss: -0.5790 - dice_coef: 0.5836 - binary_accuracy: 0.9994 - val_loss: -0.5559 - val_dice_coef: 0.5662 - val_binary_accuracy: 0.9994 - lr: 1.4000e-04
# Epoch 18/250
# 43/43 [==============================] - ETA: 0s - loss: -0.6357 - dice_coef: 0.6392 - binary_accuracy: 0.9995
# Epoch 18: val_loss did not improve from -0.55703
# 43/43 [==============================] - 11s 265ms/step - loss: -0.6357 - dice_coef: 0.6392 - binary_accuracy: 0.9995 - val_loss: -0.5283 - val_dice_coef: 0.5379 - val_binary_accuracy: 0.9992 - lr: 1.4000e-04
# Epoch 19/250
# 43/43 [==============================] - ETA: 0s - loss: -0.6416 - dice_coef: 0.6439 - binary_accuracy: 0.9995
# Epoch 19: val_loss did not improve from -0.55703
# 43/43 [==============================] - 11s 264ms/step - loss: -0.6416 - dice_coef: 0.6439 - binary_accuracy: 0.9995 - val_loss: -0.5196 - val_dice_coef: 0.5308 - val_binary_accuracy: 0.9994 - lr: 1.4000e-04
# Epoch 20/250
# 43/43 [==============================] - ETA: 0s - loss: -0.6227 - dice_coef: 0.6225 - binary_accuracy: 0.9995
# Epoch 20: val_loss improved from -0.55703 to -0.59076, saving model to checkpoint-020-0.599.hdf5
# 43/43 [==============================] - 12s 271ms/step - loss: -0.6227 - dice_coef: 0.6225 - binary_accuracy: 0.9995 - val_loss: -0.5908 - val_dice_coef: 0.5987 - val_binary_accuracy: 0.9994 - lr: 1.4000e-04
# Epoch 21/250
# 43/43 [==============================] - ETA: 0s - loss: -0.6573 - dice_coef: 0.6581 - binary_accuracy: 0.9996
# Epoch 21: val_loss improved from -0.59076 to -0.62038, saving model to checkpoint-021-0.628.hdf5
# 43/43 [==============================] - 11s 267ms/step - loss: -0.6573 - dice_coef: 0.6581 - binary_accuracy: 0.9996 - val_loss: -0.6204 - val_dice_coef: 0.6279 - val_binary_accuracy: 0.9994 - lr: 1.4000e-04
# Epoch 22/250
# 43/43 [==============================] - ETA: 0s - loss: -0.6809 - dice_coef: 0.6820 - binary_accuracy: 0.9996
# Epoch 22: val_loss improved from -0.62038 to -0.62048, saving model to checkpoint-022-0.629.hdf5
# 43/43 [==============================] - 11s 267ms/step - loss: -0.6809 - dice_coef: 0.6820 - binary_accuracy: 0.9996 - val_loss: -0.6205 - val_dice_coef: 0.6285 - val_binary_accuracy: 0.9995 - lr: 1.4000e-04
# Epoch 23/250
# 43/43 [==============================] - ETA: 0s - loss: -0.6872 - dice_coef: 0.6883 - binary_accuracy: 0.9996
# Epoch 23: val_loss improved from -0.62048 to -0.62825, saving model to checkpoint-023-0.636.hdf5
# 43/43 [==============================] - 11s 267ms/step - loss: -0.6872 - dice_coef: 0.6883 - binary_accuracy: 0.9996 - val_loss: -0.6282 - val_dice_coef: 0.6360 - val_binary_accuracy: 0.9995 - lr: 1.4000e-04
# Epoch 24/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7068 - dice_coef: 0.7090 - binary_accuracy: 0.9996
# Epoch 24: val_loss did not improve from -0.62825
# 43/43 [==============================] - 12s 281ms/step - loss: -0.7068 - dice_coef: 0.7090 - binary_accuracy: 0.9996 - val_loss: -0.6236 - val_dice_coef: 0.6321 - val_binary_accuracy: 0.9995 - lr: 1.4000e-04
# Epoch 25/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7061 - dice_coef: 0.7081 - binary_accuracy: 0.9996
# Epoch 25: val_loss did not improve from -0.62825
# 43/43 [==============================] - 11s 265ms/step - loss: -0.7061 - dice_coef: 0.7081 - binary_accuracy: 0.9996 - val_loss: -0.6229 - val_dice_coef: 0.6303 - val_binary_accuracy: 0.9994 - lr: 1.4000e-04
# Epoch 26/250
# 43/43 [==============================] - ETA: 0s - loss: -0.6606 - dice_coef: 0.6616 - binary_accuracy: 0.9995
# Epoch 26: val_loss did not improve from -0.62825
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.799999243114143e-05.
# 43/43 [==============================] - 12s 270ms/step - loss: -0.6606 - dice_coef: 0.6616 - binary_accuracy: 0.9995 - val_loss: -0.6138 - val_dice_coef: 0.6211 - val_binary_accuracy: 0.9994 - lr: 1.4000e-04
# Epoch 27/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7111 - dice_coef: 0.7107 - binary_accuracy: 0.9996
# Epoch 27: val_loss improved from -0.62825 to -0.65329, saving model to checkpoint-027-0.660.hdf5
# 43/43 [==============================] - 12s 269ms/step - loss: -0.7111 - dice_coef: 0.7107 - binary_accuracy: 0.9996 - val_loss: -0.6533 - val_dice_coef: 0.6601 - val_binary_accuracy: 0.9996 - lr: 9.8000e-05
# Epoch 28/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7275 - dice_coef: 0.7280 - binary_accuracy: 0.9996
# Epoch 28: val_loss improved from -0.65329 to -0.65428, saving model to checkpoint-028-0.661.hdf5
# 43/43 [==============================] - 11s 266ms/step - loss: -0.7275 - dice_coef: 0.7280 - binary_accuracy: 0.9996 - val_loss: -0.6543 - val_dice_coef: 0.6611 - val_binary_accuracy: 0.9995 - lr: 9.8000e-05
# Epoch 29/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7259 - dice_coef: 0.7282 - binary_accuracy: 0.9996
# Epoch 29: val_loss did not improve from -0.65428
# 43/43 [==============================] - 12s 269ms/step - loss: -0.7259 - dice_coef: 0.7282 - binary_accuracy: 0.9996 - val_loss: -0.6458 - val_dice_coef: 0.6529 - val_binary_accuracy: 0.9995 - lr: 9.8000e-05
# Epoch 30/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7567 - dice_coef: 0.7608 - binary_accuracy: 0.9997
# Epoch 30: val_loss improved from -0.65428 to -0.65756, saving model to checkpoint-030-0.665.hdf5
# 43/43 [==============================] - 11s 267ms/step - loss: -0.7567 - dice_coef: 0.7608 - binary_accuracy: 0.9997 - val_loss: -0.6576 - val_dice_coef: 0.6647 - val_binary_accuracy: 0.9996 - lr: 9.8000e-05
# Epoch 31/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7508 - dice_coef: 0.7499 - binary_accuracy: 0.9997
# Epoch 31: val_loss did not improve from -0.65756
# 43/43 [==============================] - 11s 265ms/step - loss: -0.7508 - dice_coef: 0.7499 - binary_accuracy: 0.9997 - val_loss: -0.6503 - val_dice_coef: 0.6579 - val_binary_accuracy: 0.9996 - lr: 9.8000e-05
# Epoch 32/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7573 - dice_coef: 0.7588 - binary_accuracy: 0.9997
# Epoch 32: val_loss improved from -0.65756 to -0.66920, saving model to checkpoint-032-0.676.hdf5
# 43/43 [==============================] - 12s 272ms/step - loss: -0.7573 - dice_coef: 0.7588 - binary_accuracy: 0.9997 - val_loss: -0.6692 - val_dice_coef: 0.6760 - val_binary_accuracy: 0.9996 - lr: 9.8000e-05
# Epoch 33/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7523 - dice_coef: 0.7530 - binary_accuracy: 0.9997
# Epoch 33: val_loss improved from -0.66920 to -0.67001, saving model to checkpoint-033-0.677.hdf5
# 43/43 [==============================] - 12s 269ms/step - loss: -0.7523 - dice_coef: 0.7530 - binary_accuracy: 0.9997 - val_loss: -0.6700 - val_dice_coef: 0.6770 - val_binary_accuracy: 0.9996 - lr: 9.8000e-05
# Epoch 34/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7623 - dice_coef: 0.7643 - binary_accuracy: 0.9997
# Epoch 34: val_loss did not improve from -0.67001
# 43/43 [==============================] - 11s 264ms/step - loss: -0.7623 - dice_coef: 0.7643 - binary_accuracy: 0.9997 - val_loss: -0.6624 - val_dice_coef: 0.6697 - val_binary_accuracy: 0.9995 - lr: 9.8000e-05
# Epoch 35/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7603 - dice_coef: 0.7621 - binary_accuracy: 0.9997
# Epoch 35: val_loss improved from -0.67001 to -0.67330, saving model to checkpoint-035-0.680.hdf5
# 43/43 [==============================] - 11s 268ms/step - loss: -0.7603 - dice_coef: 0.7621 - binary_accuracy: 0.9997 - val_loss: -0.6733 - val_dice_coef: 0.6801 - val_binary_accuracy: 0.9996 - lr: 9.8000e-05
# Epoch 36/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7568 - dice_coef: 0.7564 - binary_accuracy: 0.9997
# Epoch 36: val_loss did not improve from -0.67330
# 43/43 [==============================] - 12s 270ms/step - loss: -0.7568 - dice_coef: 0.7564 - binary_accuracy: 0.9997 - val_loss: -0.6713 - val_dice_coef: 0.6785 - val_binary_accuracy: 0.9996 - lr: 9.8000e-05
# Epoch 37/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7736 - dice_coef: 0.7730 - binary_accuracy: 0.9997
# Epoch 37: val_loss improved from -0.67330 to -0.68303, saving model to checkpoint-037-0.690.hdf5
# 43/43 [==============================] - 11s 268ms/step - loss: -0.7736 - dice_coef: 0.7730 - binary_accuracy: 0.9997 - val_loss: -0.6830 - val_dice_coef: 0.6898 - val_binary_accuracy: 0.9996 - lr: 9.8000e-05
# Epoch 38/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7652 - dice_coef: 0.7689 - binary_accuracy: 0.9997
# Epoch 38: val_loss did not improve from -0.68303
# 43/43 [==============================] - 11s 266ms/step - loss: -0.7652 - dice_coef: 0.7689 - binary_accuracy: 0.9997 - val_loss: -0.6727 - val_dice_coef: 0.6793 - val_binary_accuracy: 0.9996 - lr: 9.8000e-05
# Epoch 39/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7653 - dice_coef: 0.7684 - binary_accuracy: 0.9997
# Epoch 39: val_loss did not improve from -0.68303
# 43/43 [==============================] - 12s 269ms/step - loss: -0.7653 - dice_coef: 0.7684 - binary_accuracy: 0.9997 - val_loss: -0.6809 - val_dice_coef: 0.6877 - val_binary_accuracy: 0.9996 - lr: 9.8000e-05
# Epoch 40/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7633 - dice_coef: 0.7632 - binary_accuracy: 0.9997
# Epoch 40: val_loss improved from -0.68303 to -0.68781, saving model to checkpoint-040-0.694.hdf5
# 43/43 [==============================] - 12s 269ms/step - loss: -0.7633 - dice_coef: 0.7632 - binary_accuracy: 0.9997 - val_loss: -0.6878 - val_dice_coef: 0.6942 - val_binary_accuracy: 0.9996 - lr: 9.8000e-05
# Epoch 41/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7669 - dice_coef: 0.7647 - binary_accuracy: 0.9997
# Epoch 41: val_loss did not improve from -0.68781
# 43/43 [==============================] - 11s 265ms/step - loss: -0.7669 - dice_coef: 0.7647 - binary_accuracy: 0.9997 - val_loss: -0.6569 - val_dice_coef: 0.6638 - val_binary_accuracy: 0.9995 - lr: 9.8000e-05
# Epoch 42/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7606 - dice_coef: 0.7622 - binary_accuracy: 0.9997
# Epoch 42: val_loss did not improve from -0.68781
# 43/43 [==============================] - 12s 268ms/step - loss: -0.7606 - dice_coef: 0.7622 - binary_accuracy: 0.9997 - val_loss: -0.6797 - val_dice_coef: 0.6860 - val_binary_accuracy: 0.9996 - lr: 9.8000e-05
# Epoch 43/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7743 - dice_coef: 0.7755 - binary_accuracy: 0.9997
# Epoch 43: val_loss did not improve from -0.68781
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.859999266453087e-05.
# 43/43 [==============================] - 11s 264ms/step - loss: -0.7743 - dice_coef: 0.7755 - binary_accuracy: 0.9997 - val_loss: -0.6852 - val_dice_coef: 0.6911 - val_binary_accuracy: 0.9996 - lr: 9.8000e-05
# Epoch 44/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7754 - dice_coef: 0.7789 - binary_accuracy: 0.9997
# Epoch 44: val_loss improved from -0.68781 to -0.68842, saving model to checkpoint-044-0.695.hdf5
# 43/43 [==============================] - 12s 268ms/step - loss: -0.7754 - dice_coef: 0.7789 - binary_accuracy: 0.9997 - val_loss: -0.6884 - val_dice_coef: 0.6950 - val_binary_accuracy: 0.9996 - lr: 6.8600e-05
# Epoch 45/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7956 - dice_coef: 0.7951 - binary_accuracy: 0.9997
# Epoch 45: val_loss did not improve from -0.68842
# 43/43 [==============================] - 11s 265ms/step - loss: -0.7956 - dice_coef: 0.7951 - binary_accuracy: 0.9997 - val_loss: -0.6883 - val_dice_coef: 0.6950 - val_binary_accuracy: 0.9996 - lr: 6.8600e-05
# Epoch 46/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7913 - dice_coef: 0.7927 - binary_accuracy: 0.9997
# Epoch 46: val_loss improved from -0.68842 to -0.69020, saving model to checkpoint-046-0.697.hdf5
# 43/43 [==============================] - 12s 272ms/step - loss: -0.7913 - dice_coef: 0.7927 - binary_accuracy: 0.9997 - val_loss: -0.6902 - val_dice_coef: 0.6968 - val_binary_accuracy: 0.9996 - lr: 6.8600e-05
# Epoch 47/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7949 - dice_coef: 0.7943 - binary_accuracy: 0.9997
# Epoch 47: val_loss improved from -0.69020 to -0.69047, saving model to checkpoint-047-0.697.hdf5
# 43/43 [==============================] - 12s 268ms/step - loss: -0.7949 - dice_coef: 0.7943 - binary_accuracy: 0.9997 - val_loss: -0.6905 - val_dice_coef: 0.6971 - val_binary_accuracy: 0.9996 - lr: 6.8600e-05
# Epoch 48/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7955 - dice_coef: 0.7944 - binary_accuracy: 0.9997
# Epoch 48: val_loss did not improve from -0.69047
# 43/43 [==============================] - 11s 264ms/step - loss: -0.7955 - dice_coef: 0.7944 - binary_accuracy: 0.9997 - val_loss: -0.6825 - val_dice_coef: 0.6892 - val_binary_accuracy: 0.9996 - lr: 6.8600e-05
# Epoch 49/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8028 - dice_coef: 0.8037 - binary_accuracy: 0.9997
# Epoch 49: val_loss did not improve from -0.69047
# 43/43 [==============================] - 12s 269ms/step - loss: -0.8028 - dice_coef: 0.8037 - binary_accuracy: 0.9997 - val_loss: -0.6894 - val_dice_coef: 0.6960 - val_binary_accuracy: 0.9996 - lr: 6.8600e-05
# Epoch 50/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7989 - dice_coef: 0.8000 - binary_accuracy: 0.9997
# Epoch 50: val_loss did not improve from -0.69047
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 4.801999384653754e-05.
# 43/43 [==============================] - 11s 265ms/step - loss: -0.7989 - dice_coef: 0.8000 - binary_accuracy: 0.9997 - val_loss: -0.6870 - val_dice_coef: 0.6937 - val_binary_accuracy: 0.9996 - lr: 6.8600e-05
# Epoch 51/250
# 43/43 [==============================] - ETA: 0s - loss: -0.7988 - dice_coef: 0.7974 - binary_accuracy: 0.9997
# Epoch 51: val_loss improved from -0.69047 to -0.69283, saving model to checkpoint-051-0.699.hdf5
# 43/43 [==============================] - 11s 268ms/step - loss: -0.7988 - dice_coef: 0.7974 - binary_accuracy: 0.9997 - val_loss: -0.6928 - val_dice_coef: 0.6994 - val_binary_accuracy: 0.9996 - lr: 4.8020e-05
# Epoch 52/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8034 - dice_coef: 0.8027 - binary_accuracy: 0.9997
# Epoch 52: val_loss did not improve from -0.69283
# 43/43 [==============================] - 12s 270ms/step - loss: -0.8034 - dice_coef: 0.8027 - binary_accuracy: 0.9997 - val_loss: -0.6875 - val_dice_coef: 0.6939 - val_binary_accuracy: 0.9996 - lr: 4.8020e-05
# Epoch 53/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8033 - dice_coef: 0.8067 - binary_accuracy: 0.9997
# Epoch 53: val_loss did not improve from -0.69283
# 43/43 [==============================] - 12s 278ms/step - loss: -0.8033 - dice_coef: 0.8067 - binary_accuracy: 0.9997 - val_loss: -0.6874 - val_dice_coef: 0.6939 - val_binary_accuracy: 0.9996 - lr: 4.8020e-05
# Epoch 54/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8009 - dice_coef: 0.8001 - binary_accuracy: 0.9997
# Epoch 54: val_loss did not improve from -0.69283
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 3.3613994673942216e-05.
# 43/43 [==============================] - 12s 271ms/step - loss: -0.8009 - dice_coef: 0.8001 - binary_accuracy: 0.9997 - val_loss: -0.6889 - val_dice_coef: 0.6954 - val_binary_accuracy: 0.9996 - lr: 4.8020e-05
# Epoch 55/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8075 - dice_coef: 0.8079 - binary_accuracy: 0.9997
# Epoch 55: val_loss did not improve from -0.69283
# 43/43 [==============================] - 11s 265ms/step - loss: -0.8075 - dice_coef: 0.8079 - binary_accuracy: 0.9997 - val_loss: -0.6866 - val_dice_coef: 0.6931 - val_binary_accuracy: 0.9996 - lr: 3.3614e-05
# Epoch 56/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8023 - dice_coef: 0.8007 - binary_accuracy: 0.9997
# Epoch 56: val_loss did not improve from -0.69283
# 43/43 [==============================] - 11s 264ms/step - loss: -0.8023 - dice_coef: 0.8007 - binary_accuracy: 0.9997 - val_loss: -0.6896 - val_dice_coef: 0.6960 - val_binary_accuracy: 0.9996 - lr: 3.3614e-05
# Epoch 57/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8073 - dice_coef: 0.8078 - binary_accuracy: 0.9997
# Epoch 57: val_loss did not improve from -0.69283
# 43/43 [==============================] - 12s 270ms/step - loss: -0.8073 - dice_coef: 0.8078 - binary_accuracy: 0.9997 - val_loss: -0.6858 - val_dice_coef: 0.6923 - val_binary_accuracy: 0.9996 - lr: 3.3614e-05
# Epoch 58/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8064 - dice_coef: 0.8089 - binary_accuracy: 0.9997
# Epoch 58: val_loss did not improve from -0.69283
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 2.3529794998466968e-05.
# 43/43 [==============================] - 11s 266ms/step - loss: -0.8064 - dice_coef: 0.8089 - binary_accuracy: 0.9997 - val_loss: -0.6867 - val_dice_coef: 0.6932 - val_binary_accuracy: 0.9996 - lr: 3.3614e-05
# Epoch 59/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8129 - dice_coef: 0.8116 - binary_accuracy: 0.9997
# Epoch 59: val_loss did not improve from -0.69283
# 43/43 [==============================] - 11s 265ms/step - loss: -0.8129 - dice_coef: 0.8116 - binary_accuracy: 0.9997 - val_loss: -0.6889 - val_dice_coef: 0.6954 - val_binary_accuracy: 0.9996 - lr: 2.3530e-05
# Epoch 60/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8131 - dice_coef: 0.8153 - binary_accuracy: 0.9997
# Epoch 60: val_loss did not improve from -0.69283
# 43/43 [==============================] - 11s 265ms/step - loss: -0.8131 - dice_coef: 0.8153 - binary_accuracy: 0.9997 - val_loss: -0.6884 - val_dice_coef: 0.6948 - val_binary_accuracy: 0.9996 - lr: 2.3530e-05
# Epoch 61/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8114 - dice_coef: 0.8101 - binary_accuracy: 0.9997
# Epoch 61: val_loss did not improve from -0.69283
# 43/43 [==============================] - 12s 269ms/step - loss: -0.8114 - dice_coef: 0.8101 - binary_accuracy: 0.9997 - val_loss: -0.6905 - val_dice_coef: 0.6969 - val_binary_accuracy: 0.9996 - lr: 2.3530e-05
# Epoch 62/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8153 - dice_coef: 0.8153 - binary_accuracy: 0.9997
# Epoch 62: val_loss did not improve from -0.69283
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1.6470857008243908e-05.
# 43/43 [==============================] - 11s 266ms/step - loss: -0.8153 - dice_coef: 0.8153 - binary_accuracy: 0.9997 - val_loss: -0.6921 - val_dice_coef: 0.6984 - val_binary_accuracy: 0.9996 - lr: 2.3530e-05
# Epoch 63/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8093 - dice_coef: 0.8045 - binary_accuracy: 0.9997
# Epoch 63: val_loss improved from -0.69283 to -0.69286, saving model to checkpoint-063-0.699.hdf5
# 43/43 [==============================] - 11s 268ms/step - loss: -0.8093 - dice_coef: 0.8045 - binary_accuracy: 0.9997 - val_loss: -0.6929 - val_dice_coef: 0.6992 - val_binary_accuracy: 0.9996 - lr: 1.6471e-05
# Epoch 64/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8199 - dice_coef: 0.8216 - binary_accuracy: 0.9997
# Epoch 64: val_loss did not improve from -0.69286
# 43/43 [==============================] - 12s 271ms/step - loss: -0.8199 - dice_coef: 0.8216 - binary_accuracy: 0.9997 - val_loss: -0.6899 - val_dice_coef: 0.6962 - val_binary_accuracy: 0.9996 - lr: 1.6471e-05
# Epoch 65/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8123 - dice_coef: 0.8112 - binary_accuracy: 0.9997
# Epoch 65: val_loss did not improve from -0.69286
# 43/43 [==============================] - 11s 265ms/step - loss: -0.8123 - dice_coef: 0.8112 - binary_accuracy: 0.9997 - val_loss: -0.6918 - val_dice_coef: 0.6981 - val_binary_accuracy: 0.9996 - lr: 1.6471e-05
# Epoch 66/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8154 - dice_coef: 0.8164 - binary_accuracy: 0.9997
# Epoch 66: val_loss improved from -0.69286 to -0.69432, saving model to checkpoint-066-0.701.hdf5
# 43/43 [==============================] - 12s 269ms/step - loss: -0.8154 - dice_coef: 0.8164 - binary_accuracy: 0.9997 - val_loss: -0.6943 - val_dice_coef: 0.7006 - val_binary_accuracy: 0.9996 - lr: 1.6471e-05
# Epoch 67/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8185 - dice_coef: 0.8197 - binary_accuracy: 0.9997
# Epoch 67: val_loss did not improve from -0.69432
# 43/43 [==============================] - 12s 271ms/step - loss: -0.8185 - dice_coef: 0.8197 - binary_accuracy: 0.9997 - val_loss: -0.6917 - val_dice_coef: 0.6981 - val_binary_accuracy: 0.9996 - lr: 1.6471e-05
# Epoch 68/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8159 - dice_coef: 0.8162 - binary_accuracy: 0.9998
# Epoch 68: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 266ms/step - loss: -0.8159 - dice_coef: 0.8162 - binary_accuracy: 0.9998 - val_loss: -0.6943 - val_dice_coef: 0.7006 - val_binary_accuracy: 0.9996 - lr: 1.6471e-05
# Epoch 69/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8191 - dice_coef: 0.8196 - binary_accuracy: 0.9998
# Epoch 69: val_loss did not improve from -0.69432
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1.1529599396453704e-05.
# 43/43 [==============================] - 11s 265ms/step - loss: -0.8191 - dice_coef: 0.8196 - binary_accuracy: 0.9998 - val_loss: -0.6938 - val_dice_coef: 0.7001 - val_binary_accuracy: 0.9996 - lr: 1.6471e-05
# Epoch 70/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8135 - dice_coef: 0.8152 - binary_accuracy: 0.9998
# Epoch 70: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 265ms/step - loss: -0.8135 - dice_coef: 0.8152 - binary_accuracy: 0.9998 - val_loss: -0.6930 - val_dice_coef: 0.6993 - val_binary_accuracy: 0.9996 - lr: 1.1530e-05
# Epoch 71/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8159 - dice_coef: 0.8156 - binary_accuracy: 0.9998
# Epoch 71: val_loss did not improve from -0.69432
# 43/43 [==============================] - 12s 270ms/step - loss: -0.8159 - dice_coef: 0.8156 - binary_accuracy: 0.9998 - val_loss: -0.6921 - val_dice_coef: 0.6984 - val_binary_accuracy: 0.9996 - lr: 1.1530e-05
# Epoch 72/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8201 - dice_coef: 0.8226 - binary_accuracy: 0.9998
# Epoch 72: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 265ms/step - loss: -0.8201 - dice_coef: 0.8226 - binary_accuracy: 0.9998 - val_loss: -0.6926 - val_dice_coef: 0.6989 - val_binary_accuracy: 0.9996 - lr: 1.1530e-05
# Epoch 73/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8161 - dice_coef: 0.8168 - binary_accuracy: 0.9998
# Epoch 73: val_loss did not improve from -0.69432
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 8.070719832176109e-06.
# 43/43 [==============================] - 11s 265ms/step - loss: -0.8161 - dice_coef: 0.8168 - binary_accuracy: 0.9998 - val_loss: -0.6928 - val_dice_coef: 0.6991 - val_binary_accuracy: 0.9996 - lr: 1.1530e-05
# Epoch 74/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8175 - dice_coef: 0.8162 - binary_accuracy: 0.9998
# Epoch 74: val_loss did not improve from -0.69432
# 43/43 [==============================] - 12s 270ms/step - loss: -0.8175 - dice_coef: 0.8162 - binary_accuracy: 0.9998 - val_loss: -0.6923 - val_dice_coef: 0.6985 - val_binary_accuracy: 0.9996 - lr: 8.0707e-06
# Epoch 75/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8180 - dice_coef: 0.8189 - binary_accuracy: 0.9998
# Epoch 75: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 266ms/step - loss: -0.8180 - dice_coef: 0.8189 - binary_accuracy: 0.9998 - val_loss: -0.6930 - val_dice_coef: 0.6993 - val_binary_accuracy: 0.9996 - lr: 8.0707e-06
# Epoch 76/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8280 - dice_coef: 0.8307 - binary_accuracy: 0.9998
# Epoch 76: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 265ms/step - loss: -0.8280 - dice_coef: 0.8307 - binary_accuracy: 0.9998 - val_loss: -0.6941 - val_dice_coef: 0.7004 - val_binary_accuracy: 0.9996 - lr: 8.0707e-06
# Epoch 77/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8228 - dice_coef: 0.8229 - binary_accuracy: 0.9998
# Epoch 77: val_loss did not improve from -0.69432
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 5.6495036915293895e-06.
# 43/43 [==============================] - 12s 271ms/step - loss: -0.8228 - dice_coef: 0.8229 - binary_accuracy: 0.9998 - val_loss: -0.6921 - val_dice_coef: 0.6985 - val_binary_accuracy: 0.9996 - lr: 8.0707e-06
# Epoch 78/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8197 - dice_coef: 0.8226 - binary_accuracy: 0.9998
# Epoch 78: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 266ms/step - loss: -0.8197 - dice_coef: 0.8226 - binary_accuracy: 0.9998 - val_loss: -0.6924 - val_dice_coef: 0.6987 - val_binary_accuracy: 0.9996 - lr: 5.6495e-06
# Epoch 79/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8157 - dice_coef: 0.8168 - binary_accuracy: 0.9998
# Epoch 79: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 265ms/step - loss: -0.8157 - dice_coef: 0.8168 - binary_accuracy: 0.9998 - val_loss: -0.6928 - val_dice_coef: 0.6991 - val_binary_accuracy: 0.9996 - lr: 5.6495e-06
# Epoch 80/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8146 - dice_coef: 0.8136 - binary_accuracy: 0.9998
# Epoch 80: val_loss did not improve from -0.69432
# 43/43 [==============================] - 12s 269ms/step - loss: -0.8146 - dice_coef: 0.8136 - binary_accuracy: 0.9998 - val_loss: -0.6937 - val_dice_coef: 0.7000 - val_binary_accuracy: 0.9996 - lr: 5.6495e-06
# Epoch 81/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8225 - dice_coef: 0.8255 - binary_accuracy: 0.9998
# Epoch 81: val_loss did not improve from -0.69432
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 3.954652584070573e-06.
# 43/43 [==============================] - 11s 266ms/step - loss: -0.8225 - dice_coef: 0.8255 - binary_accuracy: 0.9998 - val_loss: -0.6932 - val_dice_coef: 0.6995 - val_binary_accuracy: 0.9996 - lr: 5.6495e-06
# Epoch 82/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8283 - dice_coef: 0.8287 - binary_accuracy: 0.9998
# Epoch 82: val_loss did not improve from -0.69432
# 43/43 [==============================] - 12s 284ms/step - loss: -0.8283 - dice_coef: 0.8287 - binary_accuracy: 0.9998 - val_loss: -0.6936 - val_dice_coef: 0.6999 - val_binary_accuracy: 0.9996 - lr: 3.9547e-06
# Epoch 83/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8158 - dice_coef: 0.8166 - binary_accuracy: 0.9998
# Epoch 83: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 267ms/step - loss: -0.8158 - dice_coef: 0.8166 - binary_accuracy: 0.9998 - val_loss: -0.6927 - val_dice_coef: 0.6989 - val_binary_accuracy: 0.9996 - lr: 3.9547e-06
# Epoch 84/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8152 - dice_coef: 0.8157 - binary_accuracy: 0.9998
# Epoch 84: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 266ms/step - loss: -0.8152 - dice_coef: 0.8157 - binary_accuracy: 0.9998 - val_loss: -0.6933 - val_dice_coef: 0.6996 - val_binary_accuracy: 0.9996 - lr: 3.9547e-06
# Epoch 85/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8172 - dice_coef: 0.8185 - binary_accuracy: 0.9998
# Epoch 85: val_loss did not improve from -0.69432
#
# Epoch 85: ReduceLROnPlateau reducing learning rate to 2.7682568088494007e-06.
# 43/43 [==============================] - 11s 266ms/step - loss: -0.8172 - dice_coef: 0.8185 - binary_accuracy: 0.9998 - val_loss: -0.6934 - val_dice_coef: 0.6996 - val_binary_accuracy: 0.9996 - lr: 3.9547e-06
# Epoch 86/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8192 - dice_coef: 0.8183 - binary_accuracy: 0.9998
# Epoch 86: val_loss did not improve from -0.69432
# 43/43 [==============================] - 12s 269ms/step - loss: -0.8192 - dice_coef: 0.8183 - binary_accuracy: 0.9998 - val_loss: -0.6931 - val_dice_coef: 0.6994 - val_binary_accuracy: 0.9996 - lr: 2.7683e-06
# Epoch 87/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8260 - dice_coef: 0.8244 - binary_accuracy: 0.9998
# Epoch 87: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 266ms/step - loss: -0.8260 - dice_coef: 0.8244 - binary_accuracy: 0.9998 - val_loss: -0.6931 - val_dice_coef: 0.6994 - val_binary_accuracy: 0.9996 - lr: 2.7683e-06
# Epoch 88/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8211 - dice_coef: 0.8235 - binary_accuracy: 0.9998
# Epoch 88: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 265ms/step - loss: -0.8211 - dice_coef: 0.8235 - binary_accuracy: 0.9998 - val_loss: -0.6929 - val_dice_coef: 0.6992 - val_binary_accuracy: 0.9996 - lr: 2.7683e-06
# Epoch 89/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8177 - dice_coef: 0.8188 - binary_accuracy: 0.9998
# Epoch 89: val_loss did not improve from -0.69432
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 1.937779734362266e-06.
# 43/43 [==============================] - 12s 272ms/step - loss: -0.8177 - dice_coef: 0.8188 - binary_accuracy: 0.9998 - val_loss: -0.6929 - val_dice_coef: 0.6992 - val_binary_accuracy: 0.9996 - lr: 2.7683e-06
# Epoch 90/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8220 - dice_coef: 0.8226 - binary_accuracy: 0.9998
# Epoch 90: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 266ms/step - loss: -0.8220 - dice_coef: 0.8226 - binary_accuracy: 0.9998 - val_loss: -0.6932 - val_dice_coef: 0.6995 - val_binary_accuracy: 0.9996 - lr: 1.9378e-06
# Epoch 91/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8220 - dice_coef: 0.8241 - binary_accuracy: 0.9998
# Epoch 91: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 265ms/step - loss: -0.8220 - dice_coef: 0.8241 - binary_accuracy: 0.9998 - val_loss: -0.6930 - val_dice_coef: 0.6993 - val_binary_accuracy: 0.9996 - lr: 1.9378e-06
# Epoch 92/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8195 - dice_coef: 0.8164 - binary_accuracy: 0.9998
# Epoch 92: val_loss did not improve from -0.69432
# 43/43 [==============================] - 12s 271ms/step - loss: -0.8195 - dice_coef: 0.8164 - binary_accuracy: 0.9998 - val_loss: -0.6929 - val_dice_coef: 0.6992 - val_binary_accuracy: 0.9996 - lr: 1.9378e-06
# Epoch 93/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8250 - dice_coef: 0.8276 - binary_accuracy: 0.9998
# Epoch 93: val_loss did not improve from -0.69432
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 1.356445750388957e-06.
# 43/43 [==============================] - 11s 266ms/step - loss: -0.8250 - dice_coef: 0.8276 - binary_accuracy: 0.9998 - val_loss: -0.6935 - val_dice_coef: 0.6998 - val_binary_accuracy: 0.9996 - lr: 1.9378e-06
# Epoch 94/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8213 - dice_coef: 0.8221 - binary_accuracy: 0.9998
# Epoch 94: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 266ms/step - loss: -0.8213 - dice_coef: 0.8221 - binary_accuracy: 0.9998 - val_loss: -0.6932 - val_dice_coef: 0.6995 - val_binary_accuracy: 0.9996 - lr: 1.3564e-06
# Epoch 95/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8173 - dice_coef: 0.8180 - binary_accuracy: 0.9998
# Epoch 95: val_loss did not improve from -0.69432
# 43/43 [==============================] - 12s 271ms/step - loss: -0.8173 - dice_coef: 0.8180 - binary_accuracy: 0.9998 - val_loss: -0.6932 - val_dice_coef: 0.6995 - val_binary_accuracy: 0.9996 - lr: 1.3564e-06
# Epoch 96/250
# 43/43 [==============================] - ETA: 0s - loss: -0.8238 - dice_coef: 0.8262 - binary_accuracy: 0.9998
# Epoch 96: val_loss did not improve from -0.69432
# 43/43 [==============================] - 11s 266ms/step - loss: -0.8238 - dice_coef: 0.8262 - binary_accuracy: 0.9998 - val_loss: -0.6935 - val_dice_coef: 0.6998 - val_binary_accuracy: 0.9996 - lr: 1.3564e-06

# %% [markdown]
# Plotting the history of training

# %%
plt.figure(figsize=(20,6))
for i, met in enumerate(['dice_coef', 'loss']):
  plt.subplot(1,2,i+1)
  plt.plot(history.history[met], color="b")
  plt.plot(history.history["val_"+met], color="g")
  plt.title('Model '+met.capitalize())
  plt.xlabel('epochs')
  plt.ylabel(met)
  plt.legend(['train', 'val'])

# %% [markdown]
# Saving model history for future use

# %%
import pickle
with open('LC_UNet_trainHistory', 'wb') as file_pi:
        pickle.dump(history.history, file_pi)
# To load history
# history = pickle.load(open('DenseNet121trainHistory', "rb"))

# %% [markdown]
# Save the model

# %%
model.save("LC_v4_UNet_cl.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model.evaluate(testX, testY)
# Out:
# 11/11 [==============================] - 2s 91ms/step - loss: -0.6935 - dice_coef: 0.6998 - binary_accuracy: 0.9996
# [-0.6934941411018372, 0.6997849345207214, 0.9996106624603271]

# %%
with strategy.scope():
  model2 = unet(input_size=(512,512,1))
  model2.load_weights("checkpoint-063-0.699.hdf5")

  model2.compile(optimizer=Adam(learning_rate=2e-4),
                loss=[dice_coef_loss],
                metrics = [dice_coef, 'binary_accuracy'])

model2.evaluate(testX, testY)
# Out:
# 11/11 [==============================] - 29s 1s/step - loss: -0.6929 - dice_coef: 0.6992 - binary_accuracy: 0.9996
# [-0.6928566098213196, 0.6991665363311768, 0.9996076226234436]

# %%
model2.save("LC_v4_UNet_best_Model_checkpoint_cl.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
j = 1
for i in range(0,8):
  test = np.squeeze(testX)[i]
  t_p = model.predict(np.reshape(test, (1,512,512,1)))

  plt.figure(figsize=(20,300))
  plt.subplot(50,3,j)
  plt.imshow(np.squeeze(test), cmap="bone")
  plt.subplot(50,3,j+1)
  plt.imshow(np.squeeze(t_p), cmap="gray")
  plt.subplot(50,3,j+2)
  plt.imshow(cv2.addWeighted(np.squeeze(test), .5, np.squeeze(t_p), .5, 0), cmap="gray")
  j += 3
# Out:
# 1/1 [==============================] - 0s 500ms/step
# 1/1 [==============================] - 0s 472ms/step
# 1/1 [==============================] - 1s 516ms/step
# 1/1 [==============================] - 0s 477ms/step
# 1/1 [==============================] - 0s 469ms/step
# 1/1 [==============================] - 1s 509ms/step
# 1/1 [==============================] - 0s 469ms/step
# 1/1 [==============================] - 0s 454ms/step

# %%
# !cp LC_v4_UNet_cl.h5 drive/MyDrive/Datasets/lc/v4/Training_Logs/1st_Trial/LC_v4_UNet.h5
# !cp LC_UNet_trainHistory drive/MyDrive/Datasets/lc/v4/Training_Logs/1st_Trial/LC_UNet_trainHistory

# %%
# !cp LC_v4_UNet_best_Model_checkpoint_cl.h5 drive/MyDrive/Datasets/lc/v4/Training_Logs/1st_Trial/LC_UNet_best_Model_checkpoint.h5

# %% [markdown]
# Loading the checkpoint model

# %% [markdown]
# Save the checkpoint model
